# %% [markdown]
# # Data Visualization Session 1

# %% [markdown]
# ### Importing the pandas library

# %%
import pandas as pd

# %% [markdown]
# ### This line reads a CSV file and parses the 'date_received' column as dates

# %%
cc = pd.read_csv("consumer_complaints.csv", parse_dates=["date_received"])
# Out:
# C:\Users\Faizan Jamil\AppData\Local\Temp\ipykernel_9604\3873099609.py:1: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   cc = pd.read_csv("consumer_complaints.csv", parse_dates=["date_received"])
# C:\Users\Faizan Jamil\AppData\Local\Temp\ipykernel_9604\3873099609.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cc = pd.read_csv("consumer_complaints.csv", parse_dates=["date_received"])

# %% [markdown]
# ### Check the type of the variable cc

# %%
type(cc)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Check the number of dimensions of the DataFrame

# %%
cc.ndim
# Out:
# 2

# %% [markdown]
# ### Display the entire DataFrame

# %%
cc
# Out:
#        date_received           product                  sub_product  \
# 0         2013-08-30          Mortgage               Other mortgage
# 1         2013-08-30          Mortgage               Other mortgage
# 2         2013-08-30  Credit reporting                          NaN
# 3         2013-08-30      Student loan     Non-federal student loan
# 4         2013-08-30   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    2014-07-01          Mortgage               Other mortgage
# 555953    2014-07-01          Mortgage               Other mortgage
# 555954    2012-07-10          Mortgage  Conventional fixed mortgage
# 555955    2015-04-14   Debt collection                I do not know
# 555956    2014-08-14   Debt collection                I do not know
#
#                                            issue  \
# 0       Loan modification,collection,foreclosure
# ...

# %% [markdown]
# ### Display the first 10 rows of the DataFrame

# %%
cc.head(10)
# Out:
#   date_received                  product  \
# 0    2013-08-30                 Mortgage
# 1    2013-08-30                 Mortgage
# 2    2013-08-30         Credit reporting
# 3    2013-08-30             Student loan
# 4    2013-08-30          Debt collection
# 5    2013-08-30              Credit card
# 6    2013-08-30              Credit card
# 7    2013-08-30  Bank account or service
# 8    2013-08-30  Bank account or service
# 9    2013-09-17                 Mortgage
#
#                               sub_product  \
# 0                          Other mortgage
# 1                          Other mortgage
# 2                                     NaN
# 3                Non-federal student loan
# 4                             Credit card
# 5                                     NaN
# 6                                     NaN
# 7                        Checking account
# 8                        Checking account
# 9  Conventional adjustable mortgage (ARM)
#
# ...

# %% [markdown]
# ### Access and print the "date_received" column

# %%
cc["date_received"]
# Out:
# 0        2013-08-30
# 1        2013-08-30
# 2        2013-08-30
# 3        2013-08-30
# 4        2013-08-30
#             ...
# 555952   2014-07-01
# 555953   2014-07-01
# 555954   2012-07-10
# 555955   2015-04-14
# 555956   2014-08-14
# Name: date_received, Length: 555957, dtype: datetime64[ns]

# %% [markdown]
# ### Assign the "date_received" column to a new variable dr

# %%
dr = cc["date_received"]

# %% [markdown]
# ### Output the 'dr' Series

# %%
dr
# Out:
# 0        2013-08-30
# 1        2013-08-30
# 2        2013-08-30
# 3        2013-08-30
# 4        2013-08-30
#             ...
# 555952   2014-07-01
# 555953   2014-07-01
# 555954   2012-07-10
# 555955   2015-04-14
# 555956   2014-08-14
# Name: date_received, Length: 555957, dtype: datetime64[ns]

# %% [markdown]
# ### Check the type of the 'dr' variable

# %%
type(dr)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Display the column labels of the DataFrame cc

# %%
cc.columns
# Out:
# Index(['date_received', 'product', 'sub_product', 'issue', 'sub_issue',
#        'consumer_complaint_narrative', 'company_public_response', 'company',
#        'state', 'zipcode', 'tags', 'consumer_consent_provided',
#        'submitted_via', 'date_sent_to_company', 'company_response_to_consumer',
#        'timely_response', 'consumer_disputed?', 'complaint_id'],
#       dtype='object')

# %% [markdown]
# ### Display the summary information about the DataFrame

# %%
cc.info
# Out:
# <bound method DataFrame.info of        date_received           product                  sub_product  \
# 0         2013-08-30          Mortgage               Other mortgage
# 1         2013-08-30          Mortgage               Other mortgage
# 2         2013-08-30  Credit reporting                          NaN
# 3         2013-08-30      Student loan     Non-federal student loan
# 4         2013-08-30   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    2014-07-01          Mortgage               Other mortgage
# 555953    2014-07-01          Mortgage               Other mortgage
# 555954    2012-07-10          Mortgage  Conventional fixed mortgage
# 555955    2015-04-14   Debt collection                I do not know
# 555956    2014-08-14   Debt collection                I do not know
#
#                                            issue  \
# 0       Loan modification,collection,foreclosure
# ...

# %% [markdown]
# ### Check the shape of the DataFrame cc

# %%
cc.shape
# Out:
# (555957, 18)

# %% [markdown]
# ### Assign the "product" column to a new variable 'product'

# %%
product = cc["product"]

# %%
product
# Out:
# 0                 Mortgage
# 1                 Mortgage
# 2         Credit reporting
# 3             Student loan
# 4          Debt collection
#                 ...
# 555952            Mortgage
# 555953            Mortgage
# 555954            Mortgage
# 555955     Debt collection
# 555956     Debt collection
# Name: product, Length: 555957, dtype: object

# %% [markdown]
# ### Get the unique values from the 'product' series

# %%
product.unique()
# Out:
# array(['Mortgage', 'Credit reporting', 'Student loan', 'Debt collection',
#        'Credit card', 'Bank account or service', 'Consumer Loan',
#        'Money transfers', 'Payday loan', 'Prepaid card',
#        'Other financial service'], dtype=object)

# %% [markdown]
# ### Get the unique values from the 'date_received' column

# %%
cc.date_received.unique()
# Out:
# <DatetimeArray>
# ['2013-08-30 00:00:00', '2013-09-17 00:00:00', '2013-09-10 00:00:00',
#  '2013-09-24 00:00:00', '2013-09-25 00:00:00', '2013-08-31 00:00:00',
#  '2013-09-01 00:00:00', '2013-10-15 00:00:00', '2013-09-02 00:00:00',
#  '2013-09-03 00:00:00',
#  ...
#  '2016-04-09 00:00:00', '2016-04-13 00:00:00', '2016-04-21 00:00:00',
#  '2016-04-19 00:00:00', '2016-04-20 00:00:00', '2016-04-15 00:00:00',
#  '2016-04-24 00:00:00', '2016-04-17 00:00:00', '2016-04-25 00:00:00',
#  '2016-04-23 00:00:00']
# Length: 1608, dtype: datetime64[ns]

# %% [markdown]
# ### Get the unique values from the 'company' column

# %%
cc.company.unique()
# Out:
# array(['U.S. Bancorp', 'Wells Fargo & Company', 'Navient Solutions, Inc.',
#        ..., 'American Billing & Collection',
#        'DEEP SOUTH FINANCIAL SERVICES INC.', 'ICUL Service Corporation'],
#       dtype=object)

# %%
cc.company
# Out:
# 0                            U.S. Bancorp
# 1                   Wells Fargo & Company
# 2                   Wells Fargo & Company
# 3                 Navient Solutions, Inc.
# 4         Resurgent Capital Services L.P.
#                        ...
# 555952                    Bank of America
# 555953       Residential Credit Solutions
# 555954                     BB&T Financial
# 555955              Global Recovery Group
# 555956       CCS Financial Services, Inc.
# Name: company, Length: 555957, dtype: object

# %% [markdown]
# ### Create a boolean mask for the condition

# %%
bol = cc.company == "U.S. Bancorp"

# %% [markdown]
# ### Filter the DataFrame based on the boolean mask

# %%
U_S_Bancorp = cc[bol]

# %% [markdown]
# ### Display the contents of the 'U_S_Bancorp' DataFrame

# %%
U_S_Bancorp
# Out:
#        date_received                  product                  sub_product  \
# 0         2013-08-30                 Mortgage               Other mortgage
# 39        2013-09-10                 Mortgage  Conventional fixed mortgage
# 49        2013-09-17              Credit card                          NaN
# 107       2013-08-30                 Mortgage               Other mortgage
# 198       2013-09-17                 Mortgage               Other mortgage
# ...              ...                      ...                          ...
# 555839    2015-01-07  Bank account or service   Other bank product/service
# 555851    2016-02-01  Bank account or service   Other bank product/service
# 555869    2015-03-20  Bank account or service   Other bank product/service
# 555877    2015-12-31            Consumer Loan                 Vehicle loan
# 555949    2016-03-16  Bank account or service             Checking account
#
#                                            issue sub_issue  \
# ...

# %% [markdown]
# ### Filter the DataFrame based on the company name "Wells Fargo & Company"

# %%
Wells_Fargo_Company = cc[cc.company == "Wells Fargo & Company"]

# %%
Wells_Fargo_Company
# Out:
#        date_received                  product                  sub_product  \
# 1         2013-08-30                 Mortgage               Other mortgage
# 2         2013-08-30         Credit reporting                          NaN
# 6         2013-08-30              Credit card                          NaN
# 13        2013-08-30                 Mortgage               Other mortgage
# 23        2013-09-10          Debt collection                  Credit card
# ...              ...                      ...                          ...
# 555917    2013-11-13                 Mortgage               Other mortgage
# 555924    2015-09-24                 Mortgage               Other mortgage
# 555926    2013-09-04                 Mortgage               Other mortgage
# 555939    2013-04-15             Student loan     Non-federal student loan
# 555948    2014-05-09  Bank account or service  (CD) Certificate of deposit
#
# ...

# %% [markdown]
# ### Sort the DataFrame by the 'date_received' column in descending order

# %%
cc.date_received.sort_values(ascending = False)
# Out:
# 526948   2016-04-25
# 534604   2016-04-25
# 526420   2016-04-25
# 529138   2016-04-25
# 534046   2016-04-25
#             ...
# 441506   2011-12-01
# 441838   2011-12-01
# 441839   2011-12-01
# 441502   2011-12-01
# 441900   2011-12-01
# Name: date_received, Length: 555957, dtype: datetime64[ns]
